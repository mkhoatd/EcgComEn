# %%
import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from torchvision.datasets import MNIST
import json
from albumentations import Compose, Normalize
from albumentations.pytorch.transforms import ToTensorV2
import pandas as pd
import os
import os.path as osp
import gc
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm
import torch.nn.init as init
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
MODEL_NAME = 'ptfull_24_6_classes'

# %%
# !unzip '/content/drive/MyDrive/ecgtrain/downsample_custom_cut_24_6_classes_8_2_dataset.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: downsample_24_train_data/PAB/217-63425.png
#   inflating: downsample_24_train_data/PAB/107-40273.png
#   inflating: downsample_24_train_data/PAB/217-44517.png
#   inflating: downsample_24_train_data/PAB/217-61907.png
#   inflating: downsample_24_train_data/PAB/217-21052.png
#   inflating: downsample_24_train_data/PAB/107-47181.png
#   inflating: downsample_24_train_data/PAB/217-4370.png
#   inflating: downsample_24_train_data/PAB/217-28419.png
#   inflating: downsample_24_train_data/PAB/107-3269.png
#   inflating: downsample_24_train_data/PAB/107-59385.png
#   inflating: downsample_24_train_data/PAB/217-472.png
#   inflating: downsample_24_train_data/PAB/107-51555.png
#   inflating: downsample_24_train_data/PAB/217-61264.png
#   inflating: downsample_24_train_data/PAB/217-655.png
#   inflating: downsample_24_train_data/PAB/217-1580.png
#   inflating: downsample_24_train_data/PAB/107-35219.png
#   inflating: downsample_24_train_data/PAB/217-24129.png
#   inflating: downsample_24_train_data/PAB/107-6945.png
#   inflating: downsample_24_train_data/PAB/107-17357.png
#   inflating: downsample_24_train_data/PAB/107-12393.png
#   inflating: downsample_24_train_data/PAB/217-57671.png
#   inflating: downsample_24_train_data/PAB/107-50623.png
#   inflating: downsample_24_train_data/PAB/217-22889.png
#   inflating: downsample_24_train_data/PAB/217-11163.png
#   inflating: downsample_24_train_data/PAB/107-28693.png
#   inflating: downsample_24_train_data/PAB/107-21153.png
#   inflating: downsample_24_train_data/PAB/217-3444.png
#   inflating: downsample_24_train_data/PAB/107-59355.png
#   inflating: downsample_24_train_data/PAB/217-31045.png
#   inflating: downsample_24_train_data/PAB/217-55281.png
#   inflating: downsample_24_train_data/PAB/107-5445.png
#   inflating: downsample_24_train_data/PAB/107-26075.png
#   inflating: downsample_24_train_data/PAB/107-45471.png
#   inflating: downsample_24_train_data/PAB/107-45957.png
#   inflating: downsample_24_train_data/PAB/107-38273.png
#   inflating: downsample_24_train_data/PAB/217-14631.png
#   inflating: downsample_24_train_data/PAB/217-43687.png
#   inflating: downsample_24_train_data/PAB/107-36783.png
#   inflating: downsample_24_train_data/PAB/217-51780.png
#   inflating: downsample_24_train_data/PAB/107-10741.png
#   inflating: downsample_24_train_data/PAB/107-38757.png
#   inflating: downsample_24_train_data/PAB/107-33126.png
#   inflating: downsample_24_train_data/PAB/217-7906.png
#   inflating: downsample_24_train_data/PAB/107-25646.png
#   inflating: downsample_24_train_data/PAB/107-48960.png
#   inflating: downsample_24_train_data/PAB/107-54180.png
#   inflating: downsample_24_train_data/PAB/217-25182.png
#   inflating: downsample_24_train_data/PAB/107-22429.png
#   inflating: downsample_24_train_data/PAB/217-56419.png
#   inflating: downsample_24_train_data/PAB/107-34001.png
#   inflating: downsample_24_train_data/PAB/217-12234.png
#   inflating: downsample_24_train_data/PAB/107-51830.png
#   inflating: downsample_24_train_data/PAB/217-46616.png
#   inflating: downsample_24_train_data/PAB/107-43602.png
#   inflating: downsample_24_train_data/PAB/107-20296.png
#   inflating: downsample_24_train_data/PAB/107-61223.png
#   inflating: downsample_24_train_data/PAB/217-50262.png
#   inflating: downsample_24_train_data/PAB/107-13375.png
#   inflating: downsample_24_train_data/PAB/217-22736.png
#   inflating: downsample_24_train_data/PAB/217-18131.png
#   inflating: downsample_24_train_data/PAB/217-15680.png
#   inflating: downsample_24_train_data/PAB/107-54757.png
#   inflating: downsample_24_train_data/PAB/107-29178.png
#   inflating: downsample_24_train_data/PAB/217-64367.png
#   inflating: downsample_24_train_data/PAB/217-14939.png
#   inflating: downsample_24_train_data/PAB/107-52104.png
#   inflating: downsample_24_train_data/PAB/217-55126.png
#   inflating: downsample_24_train_data/PAB/217-7171.png
#   inflating: downsample_24_train_data/PAB/107-48377.png
#   inflating: downsample_24_train_data/PAB/217-24943.png
#   inflating: downsample_24_train_data/PAB/107-24020.png
#   inflating: downsample_24_train_data/PAB/217-24583.png
#   inflating: downsample_24_train_data/PAB/107-26749.png
#   inflating: downsample_24_train_data/PAB/217-40904.png
#   inflating: downsample_24_train_data/PAB/107-24971.png
#   inflating: downsample_24_train_data/PAB/217-29756.png
#   inflating: downsample_24_train_data/PAB/107-52658.png
#   inflating: downsample_24_train_data/PAB/107-36423.png
#   inflating: downsample_24_train_data/PAB/107-60213.png
#   inflating: downsample_24_train_data/PAB/107-63379.png
#   inflating: downsample_24_train_data/PAB/107-2326.png
#   inflating: downsample_24_train_data/PAB/107-31246.png
#   inflating: downsample_24_train_data/PAB/107-50566.png
#   inflating: downsample_24_train_data/PAB/217-22034.png
#   inflating: downsample_24_train_data/PAB/217-1463.png
#   inflating: downsample_24_train_data/PAB/217-19254.png
#   inflating: downsample_24_train_data/PAB/107-7315.png
#   inflating: downsample_24_train_data/PAB/107-26135.png
#   inflating: downsample_24_train_data/PAB/107-44398.png
#   inflating: downsample_24_train_data/PAB/107-47090.png
#   inflating: downsample_24_train_data/PAB/217-46674.png
#   inflating: downsample_24_train_data/PAB/217-62395.png
#   inflating: downsample_24_train_data/PAB/107-50506.png
#   inflating: downsample_24_train_data/PAB/107-4832.png
#   inflating: downsample_24_train_data/PAB/107-57241.png
#   inflating: downsample_24_train_data/PAB/107-36392.png
#   inflating: downsample_24_train_data/PAB/217-46522.png
#   inflating: downsample_24_train_data/PAB/217-57183.png
#   inflating: downsample_24_train_data/PAB/107-14692.png
#   inflating: downsample_24_train_data/PAB/107-56891.png
#   inflating: downsample_24_train_data/PAB/107-366.png
#   inflating: downsample_24_train_data/PAB/217-53500.png
#   inflating: downsample_24_train_data/PAB/217-5968.png
#   inflating: downsample_24_train_data/PAB/107-44276.png
#   inflating: downsample_24_train_data/PAB/107-43029.png
#   inflating: downsample_24_train_data/PAB/217-20691.png
#   inflating: downsample_24_train_data/PAB/107-43692.png
#   inflating: downsample_24_train_data/PAB/107-62192.png
#   inflating: downsample_24_train_data/PAB/107-34214.png
#   inflating: downsample_24_train_data/PAB/107-35796.png
#   inflating: downsample_24_train_data/PAB/107-40151.png
#   inflating: downsample_24_train_data/PAB/217-42604.png
#   inflating: downsample_24_train_data/PAB/107-24418.png
#   inflating: downsample_24_train_data/PAB/217-64911.png
#   inflating: downsample_24_train_data/PAB/217-56971.png
#   inflating: downsample_24_train_data/PAB/107-61559.png
#   inflating: downsample_24_train_data/PAB/107-27352.png
#   inflating: downsample_24_train_data/PAB/217-18772.png
#   inflating: downsample_24_train_data/PAB/107-45617.png
#   inflating: downsample_24_train_data/PAB/107-16866.png
#   inflating: downsample_24_train_data/PAB/217-4221.png
#   inflating: downsample_24_train_data/PAB/107-36513.png
#   inflating: downsample_24_train_data/PAB/217-18923.png
#   inflating: downsample_24_train_data/PAB/217-40786.png
#   inflating: downsample_24_train_data/PAB/107-20172.png
#   inflating: downsample_24_train_data/PAB/107-34767.png
#   inflating: downsample_24_train_data/PAB/107-11965.png
#   inflating: downsample_24_train_data/PAB/217-52736.png
#   inflating: downsample_24_train_data/PAB/217-60383.png
#   inflating: downsample_24_train_data/PAB/107-26195.png
#   inflating: downsample_24_train_data/PAB/217-4403.png
#   inflating: downsample_24_train_data/PAB/107-610.png
#   inflating: downsample_24_train_data/PAB/217-16186.png
#   inflating: downsample_24_train_data/PAB/217-43717.png
#   inflating: downsample_24_train_data/PAB/107-56512.png
#   inflating: downsample_24_train_data/PAB/107-43332.png
#   inflating: downsample_24_train_data/PAB/107-46232.png
#   inflating: downsample_24_train_data/PAB/217-47222.png
#   inflating: downsample_24_train_data/PAB/217-41994.png
#   inflating: downsample_24_train_data/PAB/217-19525.png
#   inflating: downsample_24_train_data/PAB/107-60396.png
#   inflating: downsample_24_train_data/PAB/107-12517.png
#   inflating: downsample_24_train_data/PAB/217-27887.png
#   inflating: downsample_24_train_data/PAB/107-20663.png
#   inflating: downsample_24_train_data/PAB/107-40121.png
#   inflating: downsample_24_train_data/PAB/107-34890.png
#   inflating: downsample_24_train_data/PAB/107-13743.png
#   inflating: downsample_24_train_data/PAB/217-5432.png
#   inflating: downsample_24_train_data/PAB/217-8862.png
#   inflating: downsample_24_train_data/PAB/107-60332.png
#   inflating: downsample_24_train_data/PAB/107-39360.png
#   inflating: downsample_24_train_data/PAB/217-17944.png
#   inflating: downsample_24_train_data/PAB/107-57942.png
#   inflating: downsample_24_train_data/PAB/217-19013.png
#   inflating: downsample_24_train_data/PAB/107-63317.png
#   inflating: downsample_24_train_data/PAB/107-46967.png
#   inflating: downsample_24_train_data/PAB/107-55755.png
#   inflating: downsample_24_train_data/PAB/217-7084.png
#   inflating: downsample_24_train_data/PAB/217-15474.png
#   inflating: downsample_24_train_data/PAB/107-16163.png
#   inflating: downsample_24_train_data/PAB/217-22094.png
#   inflating: downsample_24_train_data/PAB/217-62608.png
#   inflating: downsample_24_train_data/PAB/217-12082.png
#   inflating: downsample_24_train_data/PAB/107-50776.png
#   inflating: downsample_24_train_data/PAB/217-14689.png
#   inflating: downsample_24_train_data/PAB/107-42785.png
#   inflating: downsample_24_train_data/PAB/217-56665.png
#   inflating: downsample_24_train_data/PAB/217-26660.png
#   inflating: downsample_24_train_data/PAB/217-44674.png
#   inflating: downsample_24_train_data/PAB/217-2759.png
#   inflating: downsample_24_train_data/PAB/217-895.png
#   inflating: downsample_24_train_data/PAB/107-54972.png
#   inflating: downsample_24_train_data/PAB/217-17286.png
#   inflating: downsample_24_train_data/PAB/107-43632.png
#   inflating: downsample_24_train_data/PAB/217-12202.png
#   inflating: downsample_24_train_data/PAB/217-57333.png
#   inflating: downsample_24_train_data/PAB/217-20991.png
#   inflating: downsample_24_train_data/PAB/107-41380.png
#   inflating: downsample_24_train_data/PAB/107-5753.png
#   inflating: downsample_24_train_data/PAB/217-50168.png
#   inflating: downsample_24_train_data/PAB/217-777.png
#   inflating: downsample_24_train_data/PAB/107-5109.png
#   inflating: downsample_24_train_data/PAB/107-49050.png
#   inflating: downsample_24_train_data/PAB/107-30603.png
#   inflating: downsample_24_train_data/PAB/217-14173.png
#   inflating: downsample_24_train_data/PAB/107-6242.png
#   inflating: downsample_24_train_data/PAB/217-2154.png
#   inflating: downsample_24_train_data/PAB/107-27383.png
#   inflating: downsample_24_train_data/PAB/107-20480.png
#   inflating: downsample_24_train_data/PAB/107-64321.png
#   inflating: downsample_24_train_data/PAB/217-47159.png
#   inflating: downsample_24_train_data/PAB/217-10861.png
#   inflating: downsample_24_train_data/PAB/107-25491.png
#   inflating: downsample_24_train_data/PAB/217-53683.png
#   inflating: downsample_24_train_data/PAB/107-29363.png
#   inflating: downsample_24_train_data/PAB/217-62453.png
#   inflating: downsample_24_train_data/PAB/107-54940.png
#   inflating: downsample_24_train_data/PAB/217-38837.png
#   inflating: downsample_24_train_data/PAB/107-48683.png
#   inflating: downsample_24_train_data/PAB/217-41180.png
#   inflating: downsample_24_train_data/PAB/107-26044.png
#   inflating: downsample_24_train_data/PAB/217-62027.png
#   inflating: downsample_24_train_data/PAB/107-64259.png
#   inflating: downsample_24_train_data/PAB/107-41174.png
#   inflating: downsample_24_train_data/PAB/107-40961.png
#   inflating: downsample_24_train_data/PAB/217-45627.png
#   inflating: downsample_24_train_data/PAB/217-22374.png
#   inflating: downsample_24_train_data/PAB/107-47061.png
#   inflating: downsample_24_train_data/PAB/107-17205.png
#   inflating: downsample_24_train_data/PAB/217-64942.png
#   inflating: downsample_24_train_data/PAB/107-20753.png
#   inflating: downsample_24_train_data/PAB/217-6327.png
#   inflating: downsample_24_train_data/PAB/107-3577.png
#   inflating: downsample_24_train_data/PAB/107-18183.png
#   inflating: downsample_24_train_data/PAB/217-28387.png
#   inflating: downsample_24_train_data/PAB/217-42847.png
#   inflating: downsample_24_train_data/PAB/217-62269.png
#   inflating: downsample_24_train_data/PAB/107-50053.png
#   inflating: downsample_24_train_data/PAB/107-39056.png
#   inflating: downsample_24_train_data/PAB/107-30786.png
#   inflating: downsample_24_train_data/PAB/217-62876.png
#   inflating: downsample_24_train_data/PAB/107-62958.png
#   inflating: downsample_24_train_data/PAB/107-55369.png
#   inflating: downsample_24_train_data/PAB/217-54513.png
#   inflating: downsample_24_train_data/PAB/107-13190.png
#   inflating: downsample_24_train_data/PAB/107-64504.png
#   inflating: downsample_24_train_data/PAB/107-59414.png
#   inflating: downsample_24_train_data/PAB/107-50746.png
#   inflating: downsample_24_train_data/PAB/217-30919.png
#   inflating: downsample_24_train_data/PAB/107-6762.png
#   inflating: downsample_24_train_data/PAB/217-63212.png
#   inflating: downsample_24_train_data/PAB/107-34675.png
#   inflating: downsample_24_train_data/PAB/217-56759.png
#   inflating: downsample_24_train_data/PAB/107-18335.png
#   inflating: downsample_24_train_data/PAB/217-59269.png
#   inflating: downsample_24_train_data/PAB/217-6874.png
#   inflating: downsample_24_train_data/PAB/107-50687.png
#   inflating: downsample_24_train_data/PAB/217-15139.png
#   inflating: downsample_24_train_data/PAB/107-40027.png
#   inflating: downsample_24_train_data/PAB/107-51184.png
#   inflating: downsample_24_train_data/PAB/217-12711.png
#   inflating: downsample_24_train_data/PAB/217-15494.png
#   inflating: downsample_24_train_data/PAB/107-13466.png
#   inflating: downsample_24_train_data/PAB/107-47428.png
#   inflating: downsample_24_train_data/PAB/107-9606.png
#   inflating: downsample_24_train_data/PAB/107-9758.png
#   inflating: downsample_24_train_data/PAB/107-14077.png
#   inflating: downsample_24_train_data/PAB/107-10281.png
#   inflating: downsample_24_train_data/PAB/217-14046.png
#   inflating: downsample_24_train_data/PAB/107-6303.png
#   inflating: downsample_24_train_data/PAB/217-10251.png
#   inflating: downsample_24_train_data/PAB/107-51357.png
#   inflating: downsample_24_train_data/PAB/107-4955.png
#   inflating: downsample_24_train_data/PAB/217-21793.png
#   inflating: downsample_24_train_data/PAB/107-7714.png
#   inflating: downsample_24_train_data/PAB/107-17602.png
#   inflating: downsample_24_train_data/PAB/107-11475.png
#   inflating: downsample_24_train_data/PAB/107-16407.png
#   inflating: downsample_24_train_data/PAB/217-57641.png
#   inflating: downsample_24_train_data/PAB/107-62426.png
#   inflating: downsample_24_train_data/PAB/107-47120.png
#   inflating: downsample_24_train_data/PAB/107-9914.png
#   inflating: downsample_24_train_data/PAB/217-2307.png
#   inflating: downsample_24_train_data/PAB/107-42549.png
#   inflating: downsample_24_train_data/PAB/217-19437.png
#   inflating: downsample_24_train_data/PAB/107-60057.png
#   inflating: downsample_24_train_data/PAB/217-11779.png
#   inflating: downsample_24_train_data/PAB/217-43537.png
#   inflating: downsample_24_train_data/PAB/217-20660.png
#   inflating: downsample_24_train_data/PAB/107-28210.png
#   inflating: downsample_24_train_data/PAB/107-32585.png
#   inflating: downsample_24_train_data/PAB/107-30907.png
#   inflating: downsample_24_train_data/PAB/107-48651.png
#   inflating: downsample_24_train_data/PAB/217-41509.png
#   inflating: downsample_24_train_data/PAB/217-60562.png
#   inflating: downsample_24_train_data/PAB/107-6856.png
#   inflating: downsample_24_train_data/PAB/107-56663.png
#   inflating: downsample_24_train_data/PAB/217-16503.png
#   inflating: downsample_24_train_data/PAB/217-57427.png
#   inflating: downsample_24_train_data/PAB/107-10218.png
#   inflating: downsample_24_train_data/PAB/107-12946.png
#   inflating: downsample_24_train_data/PAB/217-51626.png
#   inflating: downsample_24_train_data/PAB/107-34921.png
#   inflating: downsample_24_train_data/PAB/107-51738.png
#   inflating: downsample_24_train_data/PAB/217-24458.png
#   inflating: downsample_24_train_data/PAB/107-35765.png
#   inflating: downsample_24_train_data/PAB/107-62396.png
#   inflating: downsample_24_train_data/PAB/217-17623.png
#   inflating: downsample_24_train_data/PAB/107-6976.png
#   inflating: downsample_24_train_data/PAB/107-35619.png
#   inflating: downsample_24_train_data/PAB/107-3669.png
#   inflating: downsample_24_train_data/PAB/217-64520.png
#   inflating: downsample_24_train_data/PAB/107-55217.png
#   inflating: downsample_24_train_data/PAB/107-41081.png
#   inflating: downsample_24_train_data/PAB/217-50933.png
#   inflating: downsample_24_train_data/PAB/217-22307.png
#   inflating: downsample_24_train_data/PAB/217-52320.png
#   inflating: downsample_24_train_data/PAB/217-64338.png
#   inflating: downsample_24_train_data/PAB/107-29721.png
#   inflating: downsample_24_train_data/PAB/217-61723.png
#   inflating: downsample_24_train_data/PAB/217-4950.png
#   inflating: downsample_24_train_data/PAB/217-43356.png
#   inflating: downsample_24_train_data/PAB/107-2785.png
#   inflating: downsample_24_train_data/PAB/217-21263.png
#   inflating: downsample_24_train_data/PAB/217-8178.png
#   inflating: downsample_24_train_data/PAB/107-3121.png
#   inflating: downsample_24_train_data/PAB/217-1884.png
#   inflating: downsample_24_train_data/PAB/107-23347.png
#   inflating: downsample_24_train_data/PAB/217-42303.png
#   inflating: downsample_24_train_data/PAB/217-39807.png
#   inflating: downsample_24_train_data/PAB/107-42999.png
#   inflating: downsample_24_train_data/PAB/107-50413.png
#   inflating: downsample_24_train_data/PAB/217-21083.png
#   inflating: downsample_24_train_data/PAB/107-7619.png
#   inflating: downsample_24_train_data/PAB/107-44644.png
#   inflating: downsample_24_train_data/PAB/217-41422.png
#   inflating: downsample_24_train_data/PAB/107-4864.png
#   inflating: downsample_24_train_data/PAB/217-53739.png
#   inflating: downsample_24_train_data/PAB/217-42634.png
#   inflating: downsample_24_train_data/PAB/217-27950.png
#   inflating: downsample_24_train_data/PAB/107-56543.png
#   inflating: downsample_24_train_data/PAB/217-7874.png
#   inflating: downsample_24_train_data/PAB/107-46875.png
#   inflating: downsample_24_train_data/PAB/107-23654.png
#   inflating: downsample_24_train_data/PAB/217-9257.png
#   inflating: downsample_24_train_data/PAB/217-173.png
#   inflating: downsample_24_train_data/PAB/107-44734.png
#   inflating: downsample_24_train_data/PAB/217-6651.png
#   inflating: downsample_24_train_data/PAB/107-50596.png
#   inflating: downsample_24_train_data/PAB/217-54336.png
#   inflating: downsample_24_train_data/PAB/217-3710.png
#   inflating: downsample_24_train_data/PAB/107-7130.png
#   inflating: downsample_24_train_data/PAB/107-14631.png
#   inflating: downsample_24_train_data/PAB/217-17684.png
#   inflating: downsample_24_train_data/PAB/107-54849.png
#   inflating: downsample_24_train_data/PAB/107-48929.png
#   inflating: downsample_24_train_data/PAB/217-6709.png
#   inflating: downsample_24_train_data/PAB/107-35375.png
#   inflating: downsample_24_train_data/PAB/217-5704.png
#   inflating: downsample_24_train_data/PAB/107-61190.png
#   inflating: downsample_24_train_data/PAB/217-14075.png
#   inflating: downsample_24_train_data/PAB/217-2244.png
#   inflating: downsample_24_train_data/PAB/107-23716.png
#   inflating: downsample_24_train_data/PAB/107-35311.png
#   inflating: downsample_24_train_data/PAB/107-16712.png
#   inflating: downsample_24_train_data/PAB/107-43572.png
#   inflating: downsample_24_train_data/PAB/217-29603.png
#   inflating: downsample_24_train_data/PAB/107-62456.png
#   inflating: downsample_24_train_data/PAB/107-53974.png
#   inflating: downsample_24_train_data/PAB/217-57397.png
#   inflating: downsample_24_train_data/PAB/107-42426.png
#   inflating: downsample_24_train_data/PAB/107-51889.png
#   inflating: downsample_24_train_data/PAB/107-15489.png
#   inflating: downsample_24_train_data/PAB/107-27536.png
#   inflating: downsample_24_train_data/PAB/107-51644.png
#   inflating: downsample_24_train_data/PAB/217-1369.png
#   inflating: downsample_24_train_data/PAB/217-1703.png
#   inflating: downsample_24_train_data/PAB/217-12323.png
#   inflating: downsample_24_train_data/PAB/217-15111.png
#   inflating: downsample_24_train_data/PAB/107-45073.png
#   inflating: downsample_24_train_data/PAB/217-27415.png
#   inflating: downsample_24_train_data/PAB/107-55818.png
#   inflating: downsample_24_train_data/PAB/217-29786.png
#   inflating: downsample_24_train_data/PAB/217-3922.png
#   inflating: downsample_24_train_data/PAB/107-34582.png
#   inflating: downsample_24_train_data/PAB/107-8936.png
#   inflating: downsample_24_train_data/PAB/107-38059.png
#   inflating: downsample_24_train_data/PAB/217-44088.png
#   inflating: downsample_24_train_data/PAB/217-29632.png
#   inflating: downsample_24_train_data/PAB/217-13042.png
#   inflating: downsample_24_train_data/PAB/107-22828.png
#   inflating: downsample_24_train_data/PAB/107-44764.png
#   inflating: downsample_24_train_data/PAB/107-45224.png
#   inflating: downsample_24_train_data/PAB/217-42422.png
#   inflating: downsample_24_train_data/PAB/107-5814.png
#   inflating: downsample_24_train_data/PAB/107-17450.png
#   inflating: downsample_24_train_data/PAB/217-43121.png
#   inflating: downsample_24_train_data/PAB/107-29630.png
#   inflating: downsample_24_train_data/PAB/107-21484.png
#   inflating: downsample_24_train_data/PAB/107-30088.png
#   inflating: downsample_24_train_data/PAB/217-9102.png
#   inflating: downsample_24_train_data/PAB/107-52596.png
#   inflating: downsample_24_train_data/PAB/217-60289.png
#   inflating: downsample_24_train_data/PAB/217-6148.png
#   inflating: downsample_24_train_data/PAB/107-57452.png
#   inflating: downsample_24_train_data/PAB/107-27932.png
#   inflating: downsample_24_train_data/PAB/107-50022.png
#   inflating: downsample_24_train_data/PAB/217-4283.png
#   inflating: downsample_24_train_data/PAB/107-11630.png
#   inflating: downsample_24_train_data/PAB/107-17785.png
#   inflating: downsample_24_train_data/PAB/107-39966.png
#   inflating: downsample_24_train_data/PAB/107-58068.png
#   inflating: downsample_24_train_data/PAB/107-21945.png
#   inflating: downsample_24_train_data/PAB/107-53882.png
#   inflating: downsample_24_train_data/PAB/217-7263.png
#   inflating: downsample_24_train_data/PAB/107-4221.png
#   inflating: downsample_24_train_data/PAB/107-58251.png
#   inflating: downsample_24_train_data/PAB/107-57727.png
#   inflating: downsample_24_train_data/PAB/107-61100.png
#   inflating: downsample_24_train_data/PAB/217-12741.png
#   inflating: downsample_24_train_data/PAB/217-13255.png
#   inflating: downsample_24_train_data/PAB/107-23805.png
#   inflating: downsample_24_train_data/PAB/217-38741.png
#   inflating: downsample_24_train_data/PAB/107-50381.png
#   inflating: downsample_24_train_data/PAB/107-42572.png
#   inflating: downsample_24_train_data/PAB/107-35855.png
#   inflating: downsample_24_train_data/PAB/107-151.png
#   inflating: downsample_24_train_data/PAB/107-48806.png
#   inflating: downsample_24_train_data/PAB/217-41692.png
#   inflating: downsample_24_train_data/PAB/107-38450.png
#   inflating: downsample_24_train_data/PAB/217-17498.png
#   inflating: downsample_24_train_data/PAB/107-10647.png
#   inflating: downsample_24_train_data/PAB/217-25729.png
#   inflating: downsample_24_train_data/PAB/107-7683.png
#   inflating: downsample_24_train_data/PAB/217-26959.png
#   inflating: downsample_24_train_data/PAB/107-40726.png
#   inflating: downsample_24_train_data/PAB/107-48039.png
#   inflating: downsample_24_train_data/PAB/217-57611.png
#   inflating: downsample_24_train_data/PAB/107-48621.png
#   inflating: downsample_24_train_data/PAB/107-31152.png
#   inflating: downsample_24_train_data/PAB/107-56328.png
#   inflating: downsample_24_train_data/PAB/217-22189.png
#   inflating: downsample_24_train_data/PAB/217-13954.png
#   inflating: downsample_24_train_data/PAB/107-32555.png
#   inflating: downsample_24_train_data/PAB/107-58342.png
#   inflating: downsample_24_train_data/PAB/107-4619.png
#   inflating: downsample_24_train_data/PAB/107-11904.png
#   inflating: downsample_24_train_data/PAB/217-19196.png
#   inflating: downsample_24_train_data/PAB/107-12609.png
#   inflating: downsample_24_train_data/PAB/217-62788.png
#   inflating: downsample_24_train_data/PAB/217-40419.png
#   inflating: downsample_24_train_data/PAB/107-1283.png
#   inflating: downsample_24_train_data/PAB/107-34523.png
#   inflating: downsample_24_train_data/PAB/107-31397.png
#   inflating: downsample_24_train_data/PAB/217-7323.png
#   inflating: downsample_24_train_data/PAB/217-39238.png
#   inflating: downsample_24_train_data/PAB/107-59047.png
#   inflating: downsample_24_train_data/PAB/107-22127.png
#   inflating: downsample_24_train_data/PAB/107-52533.png
#   inflating: downsample_24_train_data/PAB/107-17816.png
#   inflating: downsample_24_train_data/PAB/107-62069.png
#   inflating: downsample_24_train_data/PAB/107-41501.png
#   inflating: downsample_24_train_data/PAB/107-34707.png
#   inflating: downsample_24_train_data/PAB/107-31092.png
#   inflating: downsample_24_train_data/PAB/217-60119.png
#   inflating: downsample_24_train_data/PAB/107-49755.png
#   inflating: downsample_24_train_data/PAB/217-11131.png
#   inflating: downsample_24_train_data/PAB/107-3059.png
#   inflating: downsample_24_train_data/PAB/217-51143.png
#   inflating: downsample_24_train_data/PAB/217-38954.png
#   inflating: downsample_24_train_data/PAB/107-42969.png
#   inflating: downsample_24_train_data/PAB/217-12923.png
#   inflating: downsample_24_train_data/PAB/107-10464.png
#   inflating: downsample_24_train_data/PAB/107-4038.png
#   inflating: downsample_24_train_data/PAB/217-60869.png
#   inflating: downsample_24_train_data/PAB/107-16807.png
#   inflating: downsample_24_train_data/PAB/107-40602.png
#   inflating: downsample_24_train_data/PAB/217-46979.png
#   inflating: downsample_24_train_data/PAB/217-21144.png
#   inflating: downsample_24_train_data/PAB/217-26686.png
#   inflating: downsample_24_train_data/PAB/217-64277.png
#   inflating: downsample_24_train_data/PAB/217-47648.png
#   inflating: downsample_24_train_data/PAB/217-62546.png
#   inflating: downsample_24_train_data/PAB/217-23553.png
#   inflating: downsample_24_train_data/PAB/107-23225.png
#   inflating: downsample_24_train_data/PAB/107-48500.png
#   inflating: downsample_24_train_data/PAB/217-41722.png
#   inflating: downsample_24_train_data/PAB/217-42361.png
#   inflating: downsample_24_train_data/PAB/217-59362.png
#   inflating: downsample_24_train_data/PAB/217-23735.png
#   inflating: downsample_24_train_data/PAB/107-11354.png
#   inflating: downsample_24_train_data/PAB/107-24511.png
#   inflating: downsample_24_train_data/PAB/107-15641.png
#   inflating: downsample_24_train_data/PAB/107-34308.png
#   inflating: downsample_24_train_data/PAB/217-52075.png
#   inflating: downsample_24_train_data/PAB/107-63951.png
#   inflating: downsample_24_train_data/PAB/107-22096.png
#   inflating: downsample_24_train_data/PAB/107-9304.png
#   inflating: downsample_24_train_data/PAB/107-2600.png
#   inflating: downsample_24_train_data/PAB/217-59301.png
#   inflating: downsample_24_train_data/PAB/217-55846.png
#   inflating: downsample_24_train_data/PAB/107-4252.png
#   inflating: downsample_24_train_data/PAB/217-415.png
#   inflating: downsample_24_train_data/PAB/217-7053.png
#   inflating: downsample_24_train_data/PAB/217-61567.png
#   inflating: downsample_24_train_data/PAB/107-46292.png
#   inflating: downsample_24_train_data/PAB/107-2081.png
#   inflating: downsample_24_train_data/PAB/107-39240.png
#   inflating: downsample_24_train_data/PAB/107-29333.png
#   inflating: downsample_24_train_data/PAB/107-16316.png
#   inflating: downsample_24_train_data/PAB/107-44215.png
#   inflating: downsample_24_train_data/PAB/107-22581.png
#   inflating: downsample_24_train_data/PAB/107-32697.png
#   inflating: downsample_24_train_data/PAB/217-41239.png
#   inflating: downsample_24_train_data/PAB/107-60364.png
#   inflating: downsample_24_train_data/PAB/217-60656.png
#   inflating: downsample_24_train_data/PAB/107-41891.png
#   inflating: downsample_24_train_data/PAB/107-23868.png
#   inflating: downsample_24_train_data/PAB/107-48132.png
#   inflating: downsample_24_train_data/PAB/217-59544.png
#   inflating: downsample_24_train_data/PAB/107-48592.png
#   inflating: downsample_24_train_data/PAB/107-7405.png
#   inflating: downsample_24_train_data/PAB/107-17754.png
#   inflating: downsample_24_train_data/PAB/107-45408.png
#   inflating: downsample_24_train_data/PAB/217-25525.png
#   inflating: downsample_24_train_data/PAB/107-211.png
#   inflating: downsample_24_train_data/PAB/107-48531.png
#   inflating: downsample_24_train_data/PAB/107-16836.png
#   inflating: downsample_24_train_data/PAB/107-42068.png
#   inflating: downsample_24_train_data/PAB/217-9285.png
#   inflating: downsample_24_train_data/PAB/107-9182.png
#   inflating: downsample_24_train_data/PAB/107-47889.png
#   inflating: downsample_24_train_data/PAB/107-25186.png
#   inflating: downsample_24_train_data/PAB/107-31675.png
#   inflating: downsample_24_train_data/PAB/217-7381.png
#   inflating: downsample_24_train_data/PAB/107-39086.png
#   inflating: downsample_24_train_data/PAB/107-16038.png
#   inflating: downsample_24_train_data/PAB/107-8417.png
#   inflating: downsample_24_train_data/PAB/107-15306.png
#   inflating: downsample_24_train_data/PAB/217-19225.png
#   inflating: downsample_24_train_data/PAB/107-28723.png
#   inflating: downsample_24_train_data/PAB/217-9389.png
#   inflating: downsample_24_train_data/PAB/107-60793.png
#   inflating: downsample_24_train_data/PAB/107-16253.png
#   inflating: downsample_24_train_data/PAB/217-4921.png
#   inflating: downsample_24_train_data/PAB/107-51614.png
#   inflating: downsample_24_train_data/PAB/107-49694.png
#   inflating: downsample_24_train_data/PAB/107-11170.png
#   inflating: downsample_24_train_data/PAB/217-52527.png
#   inflating: downsample_24_train_data/PAB/107-5538.png
#   inflating: downsample_24_train_data/PAB/107-10157.png
#   inflating: downsample_24_train_data/PAB/107-8446.png
#   inflating: downsample_24_train_data/PAB/217-51929.png
#   inflating: downsample_24_train_data/PAB/107-62754.png
#   inflating: downsample_24_train_data/PAB/217-62152.png
#   inflating: downsample_24_train_data/PAB/217-808.png
#   inflating: downsample_24_train_data/PAB/107-24788.png
#   inflating: downsample_24_train_data/PAB/107-62722.png
#   inflating: downsample_24_train_data/PAB/107-54297.png
#   inflating: downsample_24_train_data/PAB/107-27598.png
#   inflating: downsample_24_train_data/PAB/217-61874.png
#   inflating: downsample_24_train_data/PAB/217-23794.png
#   inflating: downsample_24_train_data/PAB/217-50108.png
#   inflating: downsample_24_train_data/PAB/217-46007.png
#   inflating: downsample_24_train_data/PAB/217-47010.png
#   inflating: downsample_24_train_data/PAB/217-45658.png
#   inflating: downsample_24_train_data/PAB/217-48081.png
#   inflating: downsample_24_train_data/PAB/107-52841.png
#   inflating: downsample_24_train_data/PAB/107-31429.png
#   inflating: downsample_24_train_data/PAB/217-60059.png
#   inflating: downsample_24_train_data/PAB/107-17938.png
#   inflating: downsample_24_train_data/PAB/217-35071.png
#   inflating: downsample_24_train_data/PAB/107-38153.png
#   inflating: downsample_24_train_data/PAB/217-48170.png
#   inflating: downsample_24_train_data/PAB/107-24328.png
#   inflating: downsample_24_train_data/PAB/217-44365.png
#   inflating: downsample_24_train_data/PAB/107-43846.png
#   inflating: downsample_24_train_data/PAB/107-35463.png
#   inflating: downsample_24_train_data/PAB/107-49295.png
#   inflating: downsample_24_train_data/PAB/107-17968.png
#   inflating: downsample_24_train_data/PAB/217-5040.png
#   inflating: downsample_24_train_data/PAB/217-56515.png
#   inflating: downsample_24_train_data/PAB/107-21821.png
#   inflating: downsample_24_train_data/PAB/107-62926.png
#   inflating: downsample_24_train_data/PAB/107-61315.png
#   inflating: downsample_24_train_data/PAB/217-10525.png
#   inflating: downsample_24_train_data/PAB/107-33879.png
#   inflating: downsample_24_train_data/PAB/217-40694.png
#   inflating: downsample_24_train_data/PAB/107-25950.png
#   inflating: downsample_24_train_data/PAB/217-22648.png
#   inflating: downsample_24_train_data/PAB/107-38574.png
#   inflating: downsample_24_train_data/PAB/217-40574.png
#   inflating: downsample_24_train_data/PAB/217-61810.png
#   inflating: downsample_24_train_data/PAB/107-19560.png
#   inflating: downsample_24_train_data/PAB/107-1897.png
#   inflating: downsample_24_train_data/PAB/107-38184.png
#   inflating: downsample_24_train_data/PAB/217-21912.png
#   inflating: downsample_24_train_data/PAB/217-18742.png
#   inflating: downsample_24_train_data/PAB/107-20600.png
#   inflating: downsample_24_train_data/PAB/107-4926.png
#   inflating: downsample_24_train_data/PAB/107-35280.png
#   inflating: downsample_24_train_data/PAB/107-2845.png
#   inflating: downsample_24_train_data/PAB/107-14721.png
#   inflating: downsample_24_train_data/PAB/107-21392.png
#   inflating: downsample_24_train_data/PAB/217-29048.png
#   inflating: downsample_24_train_data/PAB/217-16209.png
#   inflating: downsample_24_train_data/PAB/107-51409.png
#   inflating: downsample_24_train_data/PAB/107-57576.png
#   inflating: downsample_24_train_data/PAB/107-40058.png
#   inflating: downsample_24_train_data/PAB/107-8905.png
#   inflating: downsample_24_train_data/PAB/107-55248.png
#   inflating: downsample_24_train_data/PAB/107-46507.png
#   inflating: downsample_24_train_data/PAB/217-10069.png
#   inflating: downsample_24_train_data/PAB/217-46433.png
#   inflating: downsample_24_train_data/PAB/107-27964.png
#   inflating: downsample_24_train_data/PAB/107-6547.png
#   inflating: downsample_24_train_data/PAB/217-58997.png
#   inflating: downsample_24_train_data/PAB/217-6086.png
#   inflating: downsample_24_train_data/PAB/217-13872.png
#   inflating: downsample_24_train_data/PAB/217-25085.png
#   inflating: downsample_24_train_data/PAB/217-54689.png
#   inflating: downsample_24_train_data/PAB/217-24341.png
#   inflating: downsample_24_train_data/PAB/107-53361.png
#   inflating: downsample_24_train_data/PAB/217-5345.png
#   inflating: downsample_24_train_data/PAB/107-64594.png
#   inflating: downsample_24_train_data/PAB/107-16896.png
#   inflating: downsample_24_train_data/PAB/217-61414.png
#   inflating: downsample_24_train_data/PAB/107-4985.png
#   inflating: downsample_24_train_data/PAB/107-50237.png
#   inflating: downsample_24_train_data/PAB/217-292.png
#   inflating: downsample_24_train_data/PAB/107-46753.png
#   inflating: downsample_24_train_data/PAB/217-5071.png
#   inflating: downsample_24_train_data/PAB/107-1438.png
#   inflating: downsample_24_train_data/PAB/217-62907.png
#   inflating: downsample_24_train_data/PAB/217-54482.png
#   inflating: downsample_24_train_data/PAB/107-763.png
#   inflating: downsample_24_train_data/PAB/107-17173.png
#   inflating: downsample_24_train_data/PAB/107-53575.png
#   inflating: downsample_24_train_data/PAB/107-52074.png
#   inflating: downsample_24_train_data/PAB/107-58926.png
#   inflating: downsample_24_train_data/PAB/217-22917.png
#   inflating: downsample_24_train_data/PAB/107-37763.png
#   inflating: downsample_24_train_data/PAB/107-60730.png
#   inflating: downsample_24_train_data/PAB/217-39689.png
#   inflating: downsample_24_train_data/PAB/107-29968.png
#   inflating: downsample_24_train_data/PAB/107-43907.png
#   inflating: downsample_24_train_data/PAB/217-6358.png
#   inflating: downsample_24_train_data/PAB/107-22367.png
#   inflating: downsample_24_train_data/PAB/217-55252.png
#   inflating: downsample_24_train_data/PAB/107-46445.png
#   inflating: downsample_24_train_data/PAB/107-23836.png
#   inflating: downsample_24_train_data/PAB/217-9045.png
#   inflating: downsample_24_train_data/PAB/217-56635.png
#   inflating: downsample_24_train_data/PAB/107-52412.png
#   inflating: downsample_24_train_data/PAB/217-61199.png
#   inflating: downsample_24_train_data/PAB/107-42815.png
#   inflating: downsample_24_train_data/PAB/107-37027.png
#   inflating: downsample_24_train_data/PAB/107-40787.png
#   inflating: downsample_24_train_data/PAB/107-60579.png
#   inflating: downsample_24_train_data/PAB/107-19866.png
#   inflating: downsample_24_train_data/PAB/107-28539.png
#   inflating: downsample_24_train_data/PAB/217-63756.png
#   inflating: downsample_24_train_data/PAB/107-26933.png
#   inflating: downsample_24_train_data/PAB/107-25583.png
#   inflating: downsample_24_train_data/PAB/217-16125.png
#   inflating: downsample_24_train_data/PAB/217-52382.png
#   inflating: downsample_24_train_data/PAB/217-61019.png
#   inflating: downsample_24_train_data/PAB/107-52044.png
#   inflating: downsample_24_train_data/PAB/107-6087.png
#   inflating: downsample_24_train_data/PAB/107-47490.png
#   inflating: downsample_24_train_data/PAB/107-28600.png
#   inflating: downsample_24_train_data/PAB/107-19253.png
#   inflating: downsample_24_train_data/PAB/217-55396.png
#   inflating: downsample_24_train_data/PAB/217-3353.png
#   inflating: downsample_24_train_data/PAB/107-10496.png
#   inflating: downsample_24_train_data/PAB/107-37700.png
#   inflating: downsample_24_train_data/PAB/107-2295.png
#   inflating: downsample_24_train_data/PAB/107-29842.png
#   inflating: downsample_24_train_data/PAB/217-56208.png
#   inflating: downsample_24_train_data/PAB/107-7589.png
#   inflating: downsample_24_train_data/PAB/217-51504.png
#   inflating: downsample_24_train_data/PAB/107-50299.png
#   inflating: downsample_24_train_data/PAB/217-5192.png
#   inflating: downsample_24_train_data/PAB/217-53618.png
#   inflating: downsample_24_train_data/PAB/217-11599.png
#   inflating: downsample_24_train_data/PAB/107-59200.png
#   inflating: downsample_24_train_data/PAB/217-48262.png
#   inflating: downsample_24_train_data/PAB/107-10372.png
#   inflating: downsample_24_train_data/PAB/107-978.png
#   inflating: downsample_24_train_data/PAB/107-19592.png
#   inflating: downsample_24_train_data/PAB/217-9163.png
#   inflating: downsample_24_train_data/PAB/107-55063.png
#   inflating: downsample_24_train_data/PAB/107-43123.png
#   inflating: downsample_24_train_data/PAB/217-64638.png
#   inflating: downsample_24_train_data/PAB/107-13100.png
#   inflating: downsample_24_train_data/PAB/107-12822.png
#   inflating: downsample_24_train_data/PAB/107-54908.png
#   inflating: downsample_24_train_data/PAB/107-8017.png
#   inflating: downsample_24_train_data/PAB/107-49080.png
#   inflating: downsample_24_train_data/PAB/217-51050.png
#   inflating: downsample_24_train_data/PAB/217-1644.png
#   inflating: downsample_24_train_data/PAB/217-30610.png
#   inflating: downsample_24_train_data/PAB/107-54149.png
#   inflating: downsample_24_train_data/PAB/217-28095.png
#   inflating: downsample_24_train_data/PAB/107-15521.png
#   inflating: downsample_24_train_data/PAB/217-13842.png
#   inflating: downsample_24_train_data/PAB/217-18039.png
#   inflating: downsample_24_train_data/PAB/217-52350.png
#   inflating: downsample_24_train_data/PAB/217-47865.png
#   inflating: downsample_24_train_data/PAB/217-26599.png
#   inflating: downsample_24_train_data/PAB/217-59450.png
#   inflating: downsample_24_train_data/PAB/107-24542.png
#   inflating: downsample_24_train_data/PAB/217-54218.png
#   inflating: downsample_24_train_data/PAB/217-23464.png
#   inflating: downsample_24_train_data/PAB/217-59391.png
#   inflating: downsample_24_train_data/PAB/217-14262.png
#   inflating: downsample_24_train_data/PAB/217-19284.png
#   inflating: downsample_24_train_data/PAB/217-32468.png
#   inflating: downsample_24_train_data/PAB/107-60302.png
#   inflating: downsample_24_train_data/PAB/107-14203.png
#   inflating: downsample_24_train_data/PAB/107-4556.png
#   inflating: downsample_24_train_data/PAB/217-58283.png
#   inflating: downsample_24_train_data/PAB/107-4127.png
#   inflating: downsample_24_train_data/PAB/107-38972.png
#   inflating: downsample_24_train_data/PAB/217-12022.png
#   inflating: downsample_24_train_data/PAB/217-15381.png
#   inflating: downsample_24_train_data/PAB/217-2001.png
#   inflating: downsample_24_train_data/PAB/217-20721.png
#   inflating: downsample_24_train_data/PAB/107-64136.png
#   inflating: downsample_24_train_data/PAB/217-23370.png
#   inflating: downsample_24_train_data/PAB/107-64616.png
#   inflating: downsample_24_train_data/PAB/217-57825.png
#   inflating: downsample_24_train_data/PAB/107-21636.png
#   inflating: downsample_24_train_data/PAB/107-62101.png
#   inflating: downsample_24_train_data/PAB/107-25920.png
#   inflating: downsample_24_train_data/PAB/107-12180.png
#   inflating: downsample_24_train_data/PAB/107-6915.png
#   inflating: downsample_24_train_data/PAB/107-50083.png
#   inflating: downsample_24_train_data/PAB/217-51442.png
#   inflating: downsample_24_train_data/PAB/107-19497.png
#   inflating: downsample_24_train_data/PAB/107-11659.png
#   inflating: downsample_24_train_data/PAB/217-62335.png
#   inflating: downsample_24_train_data/PAB/107-28117.png
#   inflating: downsample_24_train_data/PAB/217-57302.png
#   inflating: downsample_24_train_data/PAB/107-11139.png
#   inflating: downsample_24_train_data/PAB/107-45833.png
#   inflating: downsample_24_train_data/PAB/107-28963.png
#   inflating: downsample_24_train_data/PAB/107-52717.png
#   inflating: downsample_24_train_data/PAB/107-56203.png
#   inflating: downsample_24_train_data/PAB/107-25217.png
#   inflating: downsample_24_train_data/PAB/217-6479.png
#   inflating: downsample_24_train_data/PAB/217-16814.png
#   inflating: downsample_24_train_data/PAB/217-21174.png
#   inflating: downsample_24_train_data/PAB/217-8678.png
#   inflating: downsample_24_train_data/PAB/107-16959.png
#   inflating: downsample_24_train_data/PAB/107-27503.png
#   inflating: downsample_24_train_data/PAB/107-25615.png
#   inflating: downsample_24_train_data/PAB/217-56149.png
#   inflating: downsample_24_train_data/PAB/107-8356.png
#   inflating: downsample_24_train_data/PAB/107-51770.png
#   inflating: downsample_24_train_data/PAB/107-52381.png
#   inflating: downsample_24_train_data/PAB/107-43816.png
#   inflating: downsample_24_train_data/PAB/217-20088.png
#   inflating: downsample_24_train_data/PAB/107-24878.png
#   inflating: downsample_24_train_data/PAB/107-31337.png
#   inflating: downsample_24_train_data/PAB/107-32638.png
#   inflating: downsample_24_train_data/PAB/107-2386.png
#   inflating: downsample_24_train_data/PAB/217-40480.png
#   inflating: downsample_24_train_data/PAB/217-57581.png
#   inflating: downsample_24_train_data/PAB/107-63079.png
#   inflating: downsample_24_train_data/PAB/107-40304.png
#   inflating: downsample_24_train_data/PAB/107-8263.png
#   inflating: downsample_24_train_data/PAB/107-36161.png
#   inflating: downsample_24_train_data/PAB/217-7696.png
#   inflating: downsample_24_train_data/PAB/107-57298.png
#   inflating: downsample_24_train_data/PAB/107-1499.png
#   inflating: downsample_24_train_data/PAB/107-61008.png
#   inflating: downsample_24_train_data/PAB/217-54950.png
#   inflating: downsample_24_train_data/PAB/107-40241.png
#   inflating: downsample_24_train_data/PAB/107-42489.png
#   inflating: downsample_24_train_data/PAB/107-3211.png
#   inflating: downsample_24_train_data/PAB/107-24693.png
#   inflating: downsample_24_train_data/PAB/107-54664.png
#   inflating: downsample_24_train_data/PAB/217-58787.png
#   inflating: downsample_24_train_data/PAB/107-41706.png
#   inflating: downsample_24_train_data/PAB/217-16897.png
#   inflating: downsample_24_train_data/PAB/217-46799.png
#   inflating: downsample_24_train_data/PAB/217-27767.png
#   inflating: downsample_24_train_data/PAB/107-40876.png
#   inflating: downsample_24_train_data/PAB/107-26808.png
#   inflating: downsample_24_train_data/PAB/107-15794.png
#   inflating: downsample_24_train_data/PAB/217-49591.png
#   inflating: downsample_24_train_data/PAB/107-38788.png
#   inflating: downsample_24_train_data/PAB/107-64944.png
#   inflating: downsample_24_train_data/PAB/217-63911.png
#   inflating: downsample_24_train_data/PAB/217-22979.png
#   inflating: downsample_24_train_data/PAB/217-1673.png
#   inflating: downsample_24_train_data/PAB/217-2064.png
#   inflating: downsample_24_train_data/PAB/217-60958.png
#   inflating: downsample_24_train_data/PAB/217-5374.png
#   inflating: downsample_24_train_data/PAB/107-58680.png
#   inflating: downsample_24_train_data/PAB/217-51537.png
#   inflating: downsample_24_train_data/PAB/217-51385.png
#   inflating: downsample_24_train_data/PAB/217-3102.png
#   inflating: downsample_24_train_data/PAB/107-29690.png
#   inflating: downsample_24_train_data/PAB/107-14447.png
#   inflating: downsample_24_train_data/PAB/217-45295.png
#   inflating: downsample_24_train_data/PAB/217-51324.png
#   inflating: downsample_24_train_data/PAB/107-7374.png
#   inflating: downsample_24_train_data/PAB/107-2357.png
#   inflating: downsample_24_train_data/PAB/107-46416.png
#   inflating: downsample_24_train_data/PAB/107-61529.png
#   inflating: downsample_24_train_data/PAB/107-47948.png
#   inflating: downsample_24_train_data/PAB/107-22035.png
#   inflating: downsample_24_train_data/PAB/107-6395.png
#   inflating: downsample_24_train_data/PAB/217-27623.png
#   inflating: downsample_24_train_data/PAB/217-51868.png
#   inflating: downsample_24_train_data/PAB/217-19935.png
#   inflating: downsample_24_train_data/PAB/217-10343.png
#   inflating: downsample_24_train_data/PAB/107-53176.png
#   inflating: downsample_24_train_data/PAB/107-1374.png
#   inflating: downsample_24_train_data/PAB/107-55634.png
#   inflating: downsample_24_train_data/PAB/107-53945.png
#   inflating: downsample_24_train_data/PAB/217-20509.png
#   inflating: downsample_24_train_data/PAB/107-57759.png
#   inflating: downsample_24_train_data/PAB/107-58282.png
#   inflating: downsample_24_train_data/PAB/107-22273.png
#   inflating: downsample_24_train_data/PAB/217-27741.png
#   inflating: downsample_24_train_data/PAB/107-15918.png
#   inflating: downsample_24_train_data/PAB/107-45863.png
#   inflating: downsample_24_train_data/PAB/107-27053.png
#   inflating: downsample_24_train_data/PAB/217-19407.png
#   inflating: downsample_24_train_data/PAB/217-24612.png
#   inflating: downsample_24_train_data/PAB/217-1522.png
#   inflating: downsample_24_train_data/PAB/217-49803.png
#   inflating: downsample_24_train_data/PAB/217-53229.png
#   inflating: downsample_24_train_data/PAB/217-18497.png
#   inflating: downsample_24_train_data/PAB/107-57791.png
#   inflating: downsample_24_train_data/PAB/217-51810.png
#   inflating: downsample_24_train_data/PAB/107-18579.png
#   inflating: downsample_24_train_data/PAB/217-14137.png
#   inflating: downsample_24_train_data/PAB/217-28987.png
#   inflating: downsample_24_train_data/PAB/217-42243.png
#   inflating: downsample_24_train_data/PAB/107-11996.png
#   inflating: downsample_24_train_data/PAB/217-57059.png
#   inflating: downsample_24_train_data/PAB/217-53650.png
#   inflating: downsample_24_train_data/PAB/217-47767.png
#   inflating: downsample_24_train_data/PAB/217-60474.png
#   inflating: downsample_24_train_data/PAB/107-46691.png
# ...
#   inflating: downsample_24_test_data/PAB/107_12916_12916.png
#   inflating: downsample_24_test_data/PAB/107_2386_2386.png
#   inflating: downsample_24_test_data/PAB/107_34367_34367.png
#   inflating: downsample_24_test_data/PAB/107_59813_59813.png
#   inflating: downsample_24_test_data/PAB/107_58526_58526.png
#   inflating: downsample_24_test_data/PAB/107_21329_21329.png
#   inflating: downsample_24_test_data/PAB/107_61374_61374.png
#   inflating: downsample_24_test_data/PAB/107_20600_20600.png
#   inflating: downsample_24_test_data/PAB/107_5384_5384.png
#   inflating: downsample_24_test_data/PAB/107_33064_33064.png
#   inflating: downsample_24_test_data/PAB/107_58800_58800.png
#   inflating: downsample_24_test_data/PAB/107_21123_21123.png
#   inflating: downsample_24_test_data/PAB/107_2326_2326.png
#   inflating: downsample_24_test_data/PAB/107_5229_5229.png
#   inflating: downsample_24_test_data/PAB/107_16681_16681.png
#   inflating: downsample_24_test_data/PAB/107_48531_48531.png
#   inflating: downsample_24_test_data/PAB/107_29302_29302.png
#   inflating: downsample_24_test_data/PAB/107_1803_1803.png
#   inflating: downsample_24_test_data/PAB/107_19193_19193.png
#   inflating: downsample_24_test_data/PAB/107_61254_61254.png
#   inflating: downsample_24_test_data/PAB/107_29118_29118.png
#   inflating: downsample_24_test_data/PAB/107_7803_7803.png
#   inflating: downsample_24_test_data/PAB/107_46845_46845.png
#   inflating: downsample_24_test_data/PAB/107_64290_64290.png
#   inflating: downsample_24_test_data/PAB/107_1406_1406.png
#   inflating: downsample_24_test_data/PAB/107_53056_53056.png
#   inflating: downsample_24_test_data/PAB/107_10830_10830.png
#   inflating: downsample_24_test_data/PAB/107_3121_3121.png
#   inflating: downsample_24_test_data/PAB/107_61436_61436.png
#   inflating: downsample_24_test_data/PAB/107_1897_1897.png
#   inflating: downsample_24_test_data/PAB/107_23225_23225.png
#   inflating: downsample_24_test_data/PAB/107_21212_21212.png
#   inflating: downsample_24_test_data/PAB/107_56663_56663.png
#   inflating: downsample_24_test_data/PAB/107_48651_48651.png
#   inflating: downsample_24_test_data/PAB/107_6087_6087.png
#   inflating: downsample_24_test_data/PAB/107_39391_39391.png
#   inflating: downsample_24_test_data/PAB/107_38153_38153.png
#   inflating: downsample_24_test_data/PAB/107_38029_38029.png
#   inflating: downsample_24_test_data/PAB/107_29721_29721.png
#   inflating: downsample_24_test_data/PAB/107_37608_37608.png
#   inflating: downsample_24_test_data/PAB/107_4372_4372.png
#   inflating: downsample_24_test_data/PAB/107_6242_6242.png
#   inflating: downsample_24_test_data/PAB/107_731_731.png
#   inflating: downsample_24_test_data/PAB/107_20509_20509.png
#   inflating: downsample_24_test_data/PAB/107_63442_63442.png
#   inflating: downsample_24_test_data/PAB/107_9728_9728.png
#   inflating: downsample_24_test_data/PAB/107_30241_30241.png
#   inflating: downsample_24_test_data/PAB/107_14876_14876.png
#   inflating: downsample_24_test_data/PAB/107_38819_38819.png
#   inflating: downsample_24_test_data/PAB/107_52229_52229.png
#   inflating: downsample_24_test_data/PAB/107_48437_48437.png
#   inflating: downsample_24_test_data/PAB/107_27472_27472.png
#   inflating: downsample_24_test_data/PAB/107_4955_4955.png
#   inflating: downsample_24_test_data/PAB/107_45558_45558.png
#   inflating: downsample_24_test_data/PAB/107_47763_47763.png
#   inflating: downsample_24_test_data/PAB/107_33969_33969.png
#   inflating: downsample_24_test_data/PAB/107_33458_33458.png
#   inflating: downsample_24_test_data/PAB/107_36161_36161.png
#   inflating: downsample_24_test_data/PAB/107_52318_52318.png
#   inflating: downsample_24_test_data/PAB/107_19681_19681.png
#   inflating: downsample_24_test_data/PAB/107_16836_16836.png
#   inflating: downsample_24_test_data/PAB/107_20449_20449.png
#   inflating: downsample_24_test_data/PAB/107_64707_64707.png
#   inflating: downsample_24_test_data/PAB/107_1468_1468.png
#   inflating: downsample_24_test_data/PAB/107_47090_47090.png
#   inflating: downsample_24_test_data/PAB/107_55154_55154.png
#   inflating: downsample_24_test_data/PAB/107_3454_3454.png
#   inflating: downsample_24_test_data/PAB/107_35311_35311.png
#   inflating: downsample_24_test_data/PAB/107_61714_61714.png
#   inflating: downsample_24_test_data/PAB/107_40335_40335.png
#   inflating: downsample_24_test_data/PAB/107_31816_31816.png
#   inflating: downsample_24_test_data/PAB/107_5170_5170.png
#   inflating: downsample_24_test_data/PAB/107_39606_39606.png
#   inflating: downsample_24_test_data/PAB/107_47396_47396.png
#   inflating: downsample_24_test_data/PAB/107_40817_40817.png
#   inflating: downsample_24_test_data/PAB/107_15855_15855.png
#   inflating: downsample_24_test_data/PAB/107_3184_3184.png
#   inflating: downsample_24_test_data/PAB/107_52412_52412.png
#   inflating: downsample_24_test_data/PAB/107_45104_45104.png
#   inflating: downsample_24_test_data/PAB/107_56602_56602.png
#   inflating: downsample_24_test_data/PAB/107_9150_9150.png
#   inflating: downsample_24_test_data/PAB/107_38541_38541.png
#   inflating: downsample_24_test_data/PAB/107_2969_2969.png
#   inflating: downsample_24_test_data/PAB/107_25217_25217.png
#   inflating: downsample_24_test_data/PAB/107_36304_36304.png
#   inflating: downsample_24_test_data/PAB/107_63019_63019.png
#   inflating: downsample_24_test_data/PAB/107_29485_29485.png
#   inflating: downsample_24_test_data/PAB/107_43969_43969.png
#   inflating: downsample_24_test_data/PAB/107_22488_22488.png
#   inflating: downsample_24_test_data/PAB/107_62132_62132.png
#   inflating: downsample_24_test_data/PAB/107_32911_32911.png
#   inflating: downsample_24_test_data/PAB/107_8142_8142.png
#   inflating: downsample_24_test_data/PAB/107_44245_44245.png
#   inflating: downsample_24_test_data/PAB/107_62426_62426.png
#   inflating: downsample_24_test_data/PAB/107_58402_58402.png
#   inflating: downsample_24_test_data/PAB/107_57298_57298.png
#   inflating: downsample_24_test_data/PAB/107_55571_55571.png
#   inflating: downsample_24_test_data/PAB/107_36843_36843.png
#   inflating: downsample_24_test_data/PAB/107_51706_51706.png
#   inflating: downsample_24_test_data/PAB/107_45347_45347.png
#   inflating: downsample_24_test_data/PAB/107_1588_1588.png
#   inflating: downsample_24_test_data/PAB/107_61039_61039.png
#   inflating: downsample_24_test_data/PAB/107_34123_34123.png
#   inflating: downsample_24_test_data/PAB/107_11015_11015.png
#   inflating: downsample_24_test_data/PAB/107_47611_47611.png
#   inflating: downsample_24_test_data/PAB/107_8936_8936.png
#   inflating: downsample_24_test_data/PAB/107_58126_58126.png
#   inflating: downsample_24_test_data/PAB/107_22127_22127.png
#   inflating: downsample_24_test_data/PAB/107_44152_44152.png
#   inflating: downsample_24_test_data/PAB/107_25431_25431.png
#   inflating: downsample_24_test_data/PAB/107_57124_57124.png
#   inflating: downsample_24_test_data/PAB/107_8356_8356.png
#   inflating: downsample_24_test_data/PAB/107_56_56.png
#   inflating: downsample_24_test_data/PAB/107_42845_42845.png
#   inflating: downsample_24_test_data/PAB/107_10709_10709.png
#   inflating: downsample_24_test_data/PAB/107_23041_23041.png
#   inflating: downsample_24_test_data/PAB/107_7896_7896.png
#   inflating: downsample_24_test_data/PAB/107_59170_59170.png
#   inflating: downsample_24_test_data/PAB/107_38664_38664.png
#   inflating: downsample_24_test_data/PAB/107_28693_28693.png
#   inflating: downsample_24_test_data/PAB/107_59229_59229.png
#   inflating: downsample_24_test_data/PAB/107_38939_38939.png
#   inflating: downsample_24_test_data/PAB/107_41050_41050.png
#   inflating: downsample_24_test_data/PAB/107_5599_5599.png
#   inflating: downsample_24_test_data/PAB/107_2232_2232.png
#   inflating: downsample_24_test_data/PAB/107_14262_14262.png
#   inflating: downsample_24_test_data/PAB/107_16622_16622.png
#   inflating: downsample_24_test_data/PAB/107_37240_37240.png
#   inflating: downsample_24_test_data/PAB/107_46967_46967.png
#   inflating: downsample_24_test_data/PAB/107_19560_19560.png
#   inflating: downsample_24_test_data/PAB/107_12088_12088.png
#   inflating: downsample_24_test_data/PAB/107_13283_13283.png
#   inflating: downsample_24_test_data/PAB/107_61100_61100.png
#   inflating: downsample_24_test_data/PAB/107_55481_55481.png
#   inflating: downsample_24_test_data/PAB/107_49357_49357.png
#   inflating: downsample_24_test_data/PAB/107_63829_63829.png
#   inflating: downsample_24_test_data/PAB/107_11200_11200.png
#   inflating: downsample_24_test_data/PAB/107_54634_54634.png
#   inflating: downsample_24_test_data/PAB/107_22702_22702.png
#   inflating: downsample_24_test_data/PAB/107_54908_54908.png
#   inflating: downsample_24_test_data/PAB/107_26135_26135.png
#   inflating: downsample_24_test_data/PAB/107_10066_10066.png
#   inflating: downsample_24_test_data/PAB/107_30396_30396.png
#   inflating: downsample_24_test_data/PAB/107_8753_8753.png
#   inflating: downsample_24_test_data/PAB/107_30662_30662.png
#   inflating: downsample_24_test_data/PAB/107_9060_9060.png
#   inflating: downsample_24_test_data/PAB/107_43602_43602.png
#   inflating: downsample_24_test_data/PAB/107_59998_59998.png
#   inflating: downsample_24_test_data/PAB/107_28323_28323.png
#   inflating: downsample_24_test_data/PAB/107_38273_38273.png
#   inflating: downsample_24_test_data/PAB/107_12393_12393.png
#   inflating: downsample_24_test_data/PAB/107_26993_26993.png
#   inflating: downsample_24_test_data/PAB/107_58649_58649.png
#   inflating: downsample_24_test_data/PAB/107_14751_14751.png
#   inflating: downsample_24_test_data/PAB/107_44948_44948.png
#   inflating: downsample_24_test_data/PAB/107_8047_8047.png
#   inflating: downsample_24_test_data/PAB/107_25860_25860.png
#   inflating: downsample_24_test_data/PAB/107_59293_59293.png
#   inflating: downsample_24_test_data/PAB/107_40455_40455.png
#   inflating: downsample_24_test_data/PAB/107_24971_24971.png
#   inflating: downsample_24_test_data/PAB/107_33303_33303.png
#   inflating: downsample_24_test_data/PAB/107_51644_51644.png
#   inflating: downsample_24_test_data/PAB/107_60610_60610.png
#   inflating: downsample_24_test_data/PAB/107_53270_53270.png
#   inflating: downsample_24_test_data/PAB/107_18702_18702.png
#   inflating: downsample_24_test_data/PAB/107_56512_56512.png
#   inflating: downsample_24_test_data/PAB/107_2141_2141.png
#   inflating: downsample_24_test_data/PAB/107_7253_7253.png
#   inflating: downsample_24_test_data/PAB/107_4556_4556.png
#   inflating: downsample_24_test_data/PAB/107_52687_52687.png
#   inflating: downsample_24_test_data/PAB/107_24847_24847.png
#   inflating: downsample_24_test_data/PAB/107_5475_5475.png
#   inflating: downsample_24_test_data/PAB/107_5998_5998.png
#   inflating: downsample_24_test_data/PAB/107_14447_14447.png
#   inflating: downsample_24_test_data/PAB/107_59689_59689.png
#   inflating: downsample_24_test_data/PAB/107_15579_15579.png
#   inflating: downsample_24_test_data/PAB/107_4895_4895.png
#   inflating: downsample_24_test_data/PAB/107_46475_46475.png
#   inflating: downsample_24_test_data/PAB/107_37844_37844.png
#   inflating: downsample_24_test_data/PAB/107_48285_48285.png
#   inflating: downsample_24_test_data/PAB/107_22917_22917.png
#   inflating: downsample_24_test_data/PAB/107_57393_57393.png
#   inflating: downsample_24_test_data/PAB/107_3269_3269.png
#   inflating: downsample_24_test_data/PAB/107_55755_55755.png
#   inflating: downsample_24_test_data/PAB/107_29208_29208.png
#   inflating: downsample_24_test_data/PAB/107_59569_59569.png
#   inflating: downsample_24_test_data/PAB/107_23685_23685.png
#   inflating: downsample_24_test_data/PAB/107_43237_43237.png
#   inflating: downsample_24_test_data/PAB/107_62601_62601.png
#   inflating: downsample_24_test_data/PAB/107_5324_5324.png
#   inflating: downsample_24_test_data/PAB/107_610_610.png
#   inflating: downsample_24_test_data/PAB/107_27964_27964.png
#   inflating: downsample_24_test_data/PAB/107_22796_22796.png
#   inflating: downsample_24_test_data/PAB/107_22398_22398.png
#   inflating: downsample_24_test_data/PAB/107_10249_10249.png
#   inflating: downsample_24_test_data/PAB/107_32309_32309.png
#   inflating: downsample_24_test_data/PAB/107_35463_35463.png
#   inflating: downsample_24_test_data/PAB/107_32125_32125.png
#   inflating: downsample_24_test_data/PAB/107_40632_40632.png
#   inflating: downsample_24_test_data/PAB/107_60087_60087.png
#   inflating: downsample_24_test_data/PAB/107_55003_55003.png
#   inflating: downsample_24_test_data/PAB/107_5721_5721.png
#   inflating: downsample_24_test_data/PAB/107_59935_59935.png
#   inflating: downsample_24_test_data/PAB/107_10372_10372.png
#   inflating: downsample_24_test_data/PAB/107_45957_45957.png
#   inflating: downsample_24_test_data/PAB/107_23960_23960.png
#   inflating: downsample_24_test_data/PAB/107_58251_58251.png
#   inflating: downsample_24_test_data/PAB/107_44489_44489.png
#   inflating: downsample_24_test_data/PAB/107_39700_39700.png
#   inflating: downsample_24_test_data/PAB/107_13068_13068.png
#   inflating: downsample_24_test_data/PAB/107_39271_39271.png
#   inflating: downsample_24_test_data/PAB/107_47703_47703.png
#   inflating: downsample_24_test_data/PAB/107_63707_63707.png
#   inflating: downsample_24_test_data/PAB/107_28963_28963.png
#   inflating: downsample_24_test_data/PAB/107_53331_53331.png
#   inflating: downsample_24_test_data/PAB/107_40694_40694.png
#   inflating: downsample_24_test_data/PAB/107_4497_4497.png
#   inflating: downsample_24_test_data/PAB/107_32491_32491.png
#   inflating: downsample_24_test_data/PAB/107_61948_61948.png
#   inflating: downsample_24_test_data/PAB/107_3577_3577.png
#   inflating: downsample_24_test_data/PAB/107_48776_48776.png
#   inflating: downsample_24_test_data/PAB/107_58955_58955.png
#   inflating: downsample_24_test_data/PAB/107_59109_59109.png
#   inflating: downsample_24_test_data/PAB/107_33214_33214.png
#   inflating: downsample_24_test_data/PAB/107_46046_46046.png
#   inflating: downsample_24_test_data/PAB/107_6486_6486.png
#   inflating: downsample_24_test_data/PAB/107_31366_31366.png
#   inflating: downsample_24_test_data/PAB/107_1283_1283.png
#   inflating: downsample_24_test_data/PAB/107_26012_26012.png
#   inflating: downsample_24_test_data/PAB/107_24693_24693.png
#   inflating: downsample_24_test_data/PAB/107_56807_56807.png
#   inflating: downsample_24_test_data/PAB/107_62252_62252.png
#   inflating: downsample_24_test_data/PAB/107_47825_47825.png
#   inflating: downsample_24_test_data/PAB/107_46109_46109.png
#   inflating: downsample_24_test_data/PAB/107_31152_31152.png
#   inflating: downsample_24_test_data/PAB/107_30937_30937.png
#   inflating: downsample_24_test_data/PAB/107_21667_21667.png
#   inflating: downsample_24_test_data/PAB/107_16284_16284.png
#   inflating: downsample_24_test_data/PAB/107_21912_21912.png
#   inflating: downsample_24_test_data/PAB/107_30539_30539.png
#   inflating: downsample_24_test_data/PAB/107_36543_36543.png
#   inflating: downsample_24_test_data/PAB/107_24175_24175.png
#   inflating: downsample_24_test_data/PAB/107_47977_47977.png
#   inflating: downsample_24_test_data/PAB/107_34460_34460.png
#   inflating: downsample_24_test_data/PAB/107_36698_36698.png
#   inflating: downsample_24_test_data/PAB/107_29812_29812.png
#   inflating: downsample_24_test_data/PAB/107_9334_9334.png
#   inflating: downsample_24_test_data/PAB/107_22303_22303.png
#   inflating: downsample_24_test_data/PAB/107_51800_51800.png
#   inflating: downsample_24_test_data/PAB/107_27718_27718.png
#   inflating: downsample_24_test_data/PAB/107_30847_30847.png
#   inflating: downsample_24_test_data/PAB/107_55063_55063.png
#   inflating: downsample_24_test_data/PAB/107_22005_22005.png
#   inflating: downsample_24_test_data/PAB/107_48835_48835.png
#   inflating: train.csv
#   inflating: val.csv
#   inflating: test.csv

# %%
class HeartNet(nn.Module):
    def __init__(self, num_classes=8):
        super(HeartNet, self).__init__()

        self.features = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=3, stride=1, padding=1),
            nn.ELU(inplace=True),
            nn.BatchNorm2d(64, eps=0.001),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.ELU(inplace=True),
            nn.BatchNorm2d(64, eps=0.001),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ELU(inplace=True),
            nn.BatchNorm2d(128, eps=0.001),
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            nn.ELU(inplace=True),
            nn.BatchNorm2d(128, eps=0.001),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.ELU(inplace=True),
            nn.BatchNorm2d(256, eps=0.001),
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.ELU(inplace=True),
            nn.BatchNorm2d(256, eps=0.001),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Flatten(),
            nn.Linear(16 * 16 * 256, 2048),
            nn.ELU(inplace=True),
            nn.BatchNorm1d(2048, eps=0.001),
            nn.Dropout(0.5),
            nn.Linear(2048, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        return x

# %%
class Ecg2DDataset(Dataset):
    def __init__(self, df):
        super().__init__()
        self.df = df
    def __getitem__(self, index):
        img_path = self.df.loc[index, 'path']
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        # mean = 244.4575
        # std = 39.1584
        # img = (img - mean) / std
        img = img/255.0
        img = img.reshape(1, 128, 128)
        return torch.Tensor(img).float(), int(self.df.loc[index, 'label'])
    def get_dataloader(self, pin_memory, num_workers=4, batch_size=16, shuffle=True, ):
        data_loader = DataLoader(
            self, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, pin_memory = pin_memory
        )
        return data_loader
  
    def __len__(self):
        return len(self.df)

# %%
# Load data from CSV files
train_data = pd.read_csv("train.csv")
val_data = pd.read_csv("val.csv")
test_data = pd.read_csv("test.csv")

# %%
label_mapping = {'N': 0, 'V': 1, 'PAB': 2, 'R': 3, 'L': 4, 'A': 5}
train_data = train_data.replace({'label': label_mapping})
val_data = val_data.replace({'label': label_mapping})
test_data = test_data.replace({'label': label_mapping})

# %%
DATA_PATH = 'custom_cut_data'
train_loader = Ecg2DDataset(
    train_data
).get_dataloader(
    batch_size=128,
    num_workers=os.cpu_count(),
    pin_memory=True
)
val_loader = Ecg2DDataset(
    val_data
).get_dataloader(
    batch_size=128,
    num_workers=os.cpu_count(),
    pin_memory=True,
    shuffle=False
)
test_loader = Ecg2DDataset(
    test_data
).get_dataloader(
    batch_size=128,
    num_workers=os.cpu_count(),
    pin_memory=True,
    shuffle=False
)

# %%
def load_checkpoint(path, model, optimizer=None):
    pth = torch.load(path)

    model.load_state_dict(pth['state_dict'])
    if optimizer:
        optimizer.load_state_dict(pth['optimizer'])

    print("Checkpoint {} successfully loaded".format(path))

    return pth['epoch'], pth['total_iter']


def save_checkpoint(state, path):
    torch.save(state, path)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
heartnet = HeartNet(num_classes=6).to(device)

# %%
def initialize_weights(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
        init.xavier_uniform_(m.weight.data)  # Using Xavier uniform initialization
        if m.bias is not None:
            init.constant_(m.bias.data, 0.0)  # Initialize biases to zero

heartnet.apply(initialize_weights)

optimizer = torch.optim.Adam(heartnet.parameters(), lr=1e-3)
critetion = nn.CrossEntropyLoss().to(device)

# %%
ECG_DIR = '/content/drive/MyDrive/ecgtrain'

# %%
# LOG_DIR = '/content/drive/MyDrive/ecgtrain/heartnet/logs'
LOG_DIR = osp.join(ECG_DIR, MODEL_NAME, 'logs')
# PTH_DIR = '/content/drive/MyDrive/ecgtrain/heartnet/checkpoints'
PTH_DIR = osp.join(ECG_DIR, MODEL_NAME, 'checkpoints')
if not os.path.exists(LOG_DIR):
    os.makedirs(LOG_DIR)
if not os.path.exists(PTH_DIR):
    os.makedirs(PTH_DIR)
writer = SummaryWriter(log_dir=LOG_DIR)

# %%
history_df = {}
history_df['loss']=[]
history_df['val_loss']=[]
history_df['accuracy']=[]
history_df['val_accuracy']=[]

# %%
total_iter = 0
training_epoch = 0
epochs = 10

def train_one_epoch(total_iter):
    heartnet.train()
    total_loss = 0

    gt_class = np.empty(0)
    pd_class = np.empty(0)
    for i, data in enumerate(train_loader):
        inputs, targets = data[0].to(device), data[1].to(device)
        optimizer.zero_grad()
        predictions: torch.Tensor = heartnet(inputs)
        loss = critetion(predictions, targets)
        
        classes = predictions.argmax(dim=1).reshape(-1).cpu().numpy()
        
        gt_class = np.concatenate((gt_class, data[1].numpy()))
        pd_class = np.concatenate((pd_class, classes))

        class_accuracy = sum(pd_class == gt_class) / pd_class.shape[0]
        total_loss += loss.item()
        loss.backward()
        optimizer.step()
        
        if (i + 1) % 10 == 0:
            print("\tIter [%d/%d] Loss: %.4f" % (i + 1, len(train_loader), loss.item()))
            print("\tIter [%d/%d] acc: %.4f" % (i + 1, len(train_loader), class_accuracy))
            
        if (total_iter + 1) % 1000 == 0:
            for g in optimizer.param_groups:
                lr = g['lr']
                g['lr'] *= 0.95
                
        writer.add_scalar("Train loss (iterations)", loss.item(), total_iter)
        total_iter += 1
        
    total_loss /= len(train_loader)
    class_accuracy = sum(pd_class == gt_class) / pd_class.shape[0] 
    
    print('Train loss - {:4f}'.format(total_loss))
    print('Train CLASS accuracy - {:4f}'.format(class_accuracy))

    writer.add_scalar('Train loss (epochs)', total_loss, training_epoch)
    history_df['loss'].append(total_loss)
    writer.add_scalar('Train CLASS accuracy', class_accuracy, training_epoch)
    history_df['accuracy'].append(class_accuracy)

def val():
    heartnet.eval()
    total_loss = 0

    gt_class = np.empty(0)
    pd_class = np.empty(0)
    
    with torch.no_grad():
        
        for i, data in tqdm(enumerate(val_loader)):
            inputs, targets = data[0].cuda(), data[1].cuda()
            
            predictions: torch.Tensor = heartnet(inputs)
            loss = critetion(predictions, targets)
            
            classes = predictions.argmax(dim=1).reshape(-1).cpu().numpy()
            
            gt_class = np.concatenate((gt_class, data[1].numpy()))
            pd_class = np.concatenate((pd_class, classes))

            total_loss += loss.item()
        
    total_loss /= len(val_loader)
    class_accuracy = sum(pd_class == gt_class) / pd_class.shape[0] 
    
    print('Validation loss - {:4f}'.format(total_loss))
    print('Validation CLASS accuracy - {:4f}'.format(class_accuracy))

    writer.add_scalar('Validation loss', total_loss, training_epoch)
    history_df['val_loss'].append(total_loss)
    writer.add_scalar('Validation CLASS accuracy', class_accuracy, training_epoch)
    history_df['val_accuracy'].append(class_accuracy)
    
def loop(training_epoch, epochs):
    
    for epoch in range(training_epoch, epochs):
        print(f"Epoch - {training_epoch}")
        train_one_epoch(total_iter)
        save_checkpoint({
            'state_dict': heartnet.state_dict(),
            'optimizer': optimizer.state_dict(),
            'epoch': epoch,
            'total_iter': total_iter
        }, os.path.join(PTH_DIR, f"{epoch}.pth"))
        val()
        
        training_epoch += 1
        # history_df.to_json(osp.join(ECG_DIR, MODEL_NAME, 'hist.json'), orient='record')
        json.dump(history_df, open(os.path.join(ECG_DIR, MODEL_NAME, 'hist.json'), 'w'))
    print(training_epoch)

# %%
epochs, training_epoch
# Out:
# (10, 0)

# %%
def free_cuda_mem():
  gc.collect()
  torch.cuda.empty_cache()

# %%
loop(training_epoch, epochs)

# %%
val()
# Out:
# 137it [00:21,  6.29it/s]
# Validation loss - 0.246032
# Validation CLASS accuracy - 0.944429

# %%
hist_df = json.load(open(osp.join(ECG_DIR, MODEL_NAME, 'hist.json'), 'r'))

# %%
fig, axes = plt.subplots(2, 1, figsize=(16, 8), sharex=True)
axes[0].plot(hist_df['accuracy'])
axes[0].plot(hist_df['val_accuracy'])
axes[0].set_ylabel('Accuracy')
axes[1].plot(hist_df['loss'])
axes[1].plot(hist_df['val_loss'])
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
fig.suptitle('Model performance during training')
axes[0].legend(('Train accuracy', 'Validation accuracy'))
axes[1].legend(('Train loss', 'Validation loss'))

# %%
load_checkpoint(os.path.join(PTH_DIR, f"curr.pth"), heartnet)
# Out:
# Checkpoint /content/drive/MyDrive/ecgtrain/ptfull_24_6_classes/checkpoints/curr.pth successfully loaded
# (99, 0)

# %%
gt_class = np.empty(0)
pd_class = np.empty(0)
heartnet.eval()
for i, data in tqdm(enumerate(test_loader)):
    inputs, targets = data[0].cuda(), data[1].cuda()
    
    predictions: torch.Tensor = heartnet(inputs)    
    classes = predictions.argmax(dim=1).reshape(-1).cpu().numpy()
    
    gt_class = np.concatenate((gt_class, data[1].numpy()))
    pd_class = np.concatenate((pd_class, classes))

class_accuracy = sum(pd_class == gt_class) / pd_class.shape[0]
# Out:
# 30it [00:11,  2.65it/s]

# %%
class_accuracy
# Out:
# 0.6807549175970229

# %%
cm = confusion_matrix(gt_class, pd_class)
print(cm)
sns.heatmap(cm, annot=True, xticklabels=label_mapping.keys(), yticklabels=label_mapping.keys(), fmt="d")
plt.show()
# Out:
# [[2125   50    0   13    3    3]
#  [  39    5    2    0    0    6]
#  [   0    0  405    0    0    0]
#  [ 401   63    0   25    0   10]
#  [ 168  365   18    0    0    0]
#  [  53    3    0    4    0    1]]

# %%
from sklearn.metrics import classification_report
print(classification_report(gt_class, pd_class))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.97      0.85      2194
#          1.0       0.01      0.10      0.02        52
#          2.0       0.95      1.00      0.98       405
#          3.0       0.60      0.05      0.09       499
#          4.0       0.00      0.00      0.00       551
#          5.0       0.05      0.02      0.02        61
#
#     accuracy                           0.68      3762
#    macro avg       0.40      0.36      0.33      3762
# weighted avg       0.63      0.68      0.62      3762

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(gt_class, pd_class, average='macro')
# Out:
# (0.39520160339918164, 0.3551996802837778, 0.327502904911714, None)
